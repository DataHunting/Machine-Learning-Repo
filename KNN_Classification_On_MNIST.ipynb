# %%
import numpy as np
np.seterr(over='ignore')
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"]="3"
import tensorflow as tf

# %%
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step

# %%
import matplotlib.pyplot as plt
w=10
h=10
fig = plt.figure(figsize=(8,8))
columns = 8
rows = 10
for i in range(1, columns*rows+1):
  img = x_test[i]
  fig.add_subplot(rows, columns, i)
  plt.imshow(img, cmap='gray')
plt.show()

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 28, 28)
# (10000,)

# %%
N = 60000
x_tr = []
for i in range(N):
  x_tr.append(x_train[i,:].flatten())

x_te = []
for i in range(10000):
  x_te.append(x_test[i,:].flatten())

# %%
print(len(x_tr), len(x_tr[0]))
print(len(x_te), len(x_te[0]))
# Out:
# 60000 784
# 10000 784

# %%
class KNN:  # k = 1

  def __init__(self):
    pass

  # Memorize the training data
  def train(self, X, y):
    # X is 2D of size N X D = 28X28, so each row is a sample
    # y is 1D of size N
    self.tr_x = X
    self.tr_y = y

  # For the test image
  #  find the nearest train image with minimum L1 distance from test image
  #  predict the label of the nearest training image
  def predict(self, x):
    # x is of size 28X28 = 784 for which we want to predict the label
    min_idx = None
    min_dist = 100000000
    for test_sample in range(len(self.tr_x)):
      dist = 0
      for each_value in range(len(self.tr_x[0])):
        dist += abs(float((self.tr_x[test_sample][each_value] - x[each_value])))
      if dist < min_dist:
        min_dist = dist
        min_idx = test_sample
    return self.tr_y[min_idx]

# %%
classifier = KNN()
classifier.train(x_tr, y_train)

# %%
plt.figure(figsize=(2,2))
plt.imshow(x_test[3],cmap="gray")
plt.show()
print(classifier.predict(x_te[3]))

plt.figure(figsize=(2,2))
plt.imshow(x_test[2],cmap="gray")
plt.show()
print(classifier.predict(x_te[2]))

plt.figure(figsize=(2,2))
plt.imshow(x_test[33],cmap="gray")
plt.show()
print(classifier.predict(x_te[33]))

plt.figure(figsize=(2,2))
plt.imshow(x_test[59],cmap="gray")
plt.show()
print(classifier.predict(x_te[59]))

plt.figure(figsize=(2,2))
plt.imshow(x_test[36],cmap="gray")
plt.show()
print(classifier.predict(x_te[36]))
# Out:
# 0
# 1
# 1
# 5
# 7
